# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from numpy import *
import seaborn as sb
from pandas import DataFrame

# %%
def catconsep(df):
    cat = []
    con = []
    for i in df.columns:
        if(df[i].dtypes == "object"):
            cat.append(i)
        else:
            con.append(i)
    return cat,con

# %%
def replacer(df):
    import pandas as pd
    Q = pd.DataFrame(df.isna().sum(),columns=["ct"])
    for i in Q[Q.ct > 0].index:
        if(df[i].dtypes == "object"):
            x = df[i].mode()[0]
            df[i] = df[i].fillna(x)
        else:
            x = df[i].mean()
            df[i] = df[i].fillna(x)

# %%
pd.set_option('display.max_rows',100)
pd.set_option('display.max_columns',100)

# %% [markdown]
# # Fetch datasets

# %%
train = pd.read_csv('C:/Users/Lenovo/Downloads/PROJECTS/BOSTON house price prediction/training_set.csv')
test = pd.read_csv('C:/Users/Lenovo/Downloads/PROJECTS/BOSTON house price prediction/testing_set.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %% [markdown]
# # Check for null values

# %%
train.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# # Drop unnecessary columns

# %%
train = train.drop(labels=['PoolQC', 'Fence', 'MiscFeature', 'Alley','Id'],axis=1)

# %%
train.shape
# Out:
# (1460, 76)

# %%
replacer(train)

# %%
#train.isna().sum()

# %% [markdown]
# # Define x and y

# %%
y = train[['SalePrice']]
x = train.drop('SalePrice',axis=1)

# %%
x.shape
# Out:
# (1460, 75)

# %%
y.shape
# Out:
# (1460, 1)

# %% [markdown]
# # separate cat and con

# %%
cat,con = catconsep(x)

# %%
#cat

# %%
#con

# %% [markdown]
# # Bivariate

# %%
train.corr()['SalePrice'].sort_values()
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.334901
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# GarageYrBlt      0.470177
# MasVnrArea       0.475241
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# GrLivArea        0.708624
# ...

# %%
p = list(zip(range(0,50,1),round(train.corr()['SalePrice'].sort_values(),4)))

# %%
p
# Out:
# [(0, -0.1359),
#  (1, -0.1286),
#  (2, -0.0843),
#  (3, -0.0779),
#  (4, -0.0289),
#  (5, -0.0256),
#  (6, -0.0212),
#  (7, -0.0168),
#  (8, -0.0114),
#  (9, 0.0446),
#  (10, 0.0464),
#  (11, 0.0924),
#  (12, 0.1114),
#  (13, 0.1682),
#  (14, 0.2145),
#  (15, 0.2271),
#  (16, 0.2638),
#  (17, 0.2841),
#  (18, 0.3159),
#  (19, 0.3193),
#  (20, 0.3244),
#  (21, 0.3349),
#  (22, 0.3864),
#  (23, 0.4669),
#  (24, 0.4702),
#  (25, 0.4752),
#  (26, 0.5071),
#  (27, 0.5229),
#  (28, 0.5337),
#  (29, 0.5607),
#  (30, 0.6059),
#  (31, 0.6136),
#  (32, 0.6234),
#  (33, 0.6404),
#  (34, 0.7086),
#  (35, 0.791),
#  (36, 1.0)]

# %%
imp_cols = list(train.corr()["SalePrice"].sort_values().index)[27:]
imp_cols.remove("SalePrice")

# %%
sb.heatmap(x[imp_cols].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Preprocessing

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x2 = pd.DataFrame(ss.fit_transform(x[imp_cols]),columns=imp_cols)
x1 = pd.get_dummies(x[cat])
x = x2.join(x1)

# %%
x.shape
# Out:
# (1460, 248)

# %% [markdown]
# # OLS model

# %%
from statsmodels.api import OLS, add_constant
x1 = add_constant(x)
ols = OLS(y,x1)
model1 = ols.fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     65.75
# Date:                Wed, 09 Feb 2022   Prob (F-statistic):               0.00
# Time:                        16:43:38   Log-Likelihood:                -16734.
# No. Observations:                1460   AIC:                         3.389e+04
# Df Residuals:                    1251   BIC:                         3.499e+04
# Df Model:                         208
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Divide the data in training and testing set

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=31)

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
lr = LinearRegression()
lr_model = lr.fit(xtrain,ytrain)

from sklearn.metrics import mean_absolute_error

pred = lr_model.predict(xtest)
test_error = mean_absolute_error(ytest,pred)
test_error = round(test_error,2)

pred = lr_model.predict(xtrain)
train_error = mean_absolute_error(ytrain,pred)
train_error = round(train_error,2)

print('train_error:   ', train_error)
print('test_error:    ', test_error)

if(train_error < test_error):
    print("Model Overfits")
else:
    print("No Overfitting")
# Out:
# train_error:    14035.11
# test_error:     17658255947578.05
# Model Overfits

# %% [markdown]
# # Lasso

# %%
ls = Lasso()

tuning_grid = []
x = 0.70
for i in range(0,200,1):
    x = x + 0.001
    x = round(x,3)
    tuning_grid.append(x)
    
tp={'alpha': tuning_grid}

cv = GridSearchCV(ls,tp, scoring="neg_mean_absolute_error", cv= 4)
cv_model = cv.fit(xtrain,ytrain)
cv_model.best_params_
# Out:
# {'alpha': 0.9}

# %%
ls = Lasso(alpha=0.9)
ls_model = ls.fit(xtrain,ytrain)

pred2 = ls_model.predict(xtest)

from sklearn.metrics import mean_absolute_error

test_error = mean_absolute_error(ytest,pred2)
test_error = round(test_error,2)

pred2 = ls_model.predict(xtrain)
train_error = mean_absolute_error(ytrain,pred2)
train_error = round(train_error,2)

print('train_error:  ',train_error)
print('test_error:   ', test_error)

if (train_error < test_error):
    print('Overfitting')
else:
    print('Not Overfitting')
# Out:
# train_error:   14042.89
# test_error:    20590.71
# Overfitting

# %% [markdown]
# # Ridge

# %%
rr = Ridge()

tuning_grid = []
x = 0.70
for i in range(0,200,1):
    x = x + 0.001
    x = round(x,3)
    tuning_grid.append(x)
    
tp={'alpha': tuning_grid}

cv = GridSearchCV(ls,tp, scoring="neg_mean_absolute_error", cv= 4)
cv_model = cv.fit(xtrain,ytrain)
cv_model.best_params_
# Out:
# {'alpha': 0.9}

# %%
rr = Ridge(alpha=0.9)
rr_model = ls.fit(xtrain,ytrain)

pred2 = rr_model.predict(xtest)

from sklearn.metrics import mean_absolute_error

test_error = mean_absolute_error(ytest,pred2)
test_error = round(test_error,2)

pred2 = ls_model.predict(xtrain)
train_error = mean_absolute_error(ytrain,pred2)
train_error = round(train_error,2)

print('train_error:  ',train_error)
print('test_error:   ', test_error)

if (train_error < test_error):
    print('Overfitting')
else:
    print('Not Overfitting')
# Out:
# train_error:   14042.89
# test_error:    20590.71
# Overfitting

# %% [markdown]
# # Testing dataset

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
test2 = test.drop(labels=['PoolQC', 'Fence', 'MiscFeature', 'Alley','Id'],axis=1)

# %%
replacer(test2)

# %%
test2.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %%
cat, con = catconsep(test2)

# %%
#cat

# %%
#con

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x2 = pd.DataFrame(ss.fit_transform(test2[con]),columns=con)
x1 = pd.get_dummies(test2[cat])
xnew = x2.join(x1)

# %%
xnew.shape
# Out:
# (1459, 259)

# %%
cols = xtrain.columns

# %%
xnew2 = xnew[cols]

# %%
xnew2.shape
# Out:
# (1459, 248)

# %% [markdown]
# # prediction

# %%
pred1 = lr_model.predict(xnew2)
pred2 = ls_model.predict(xnew2)
pred3 = rr_model.predict(xnew2)

# %%
test['LR_predicted_sale_price'] = pred1
test['LS_predicted_sale_price'] = pred2
test['RR_predicted_sale_price'] = pred3

# %%
test.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# ...
